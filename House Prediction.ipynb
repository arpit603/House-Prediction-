# %%
# I have used Jupyter for making this notebook

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import csv

# %% [markdown]
# ### House Prediction

# %% [markdown]
# ### Linear Regression

# %%
df = pd.read_excel('dataset.xlsx') # Reading the data
df.head() # Displaying first few columns of data
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1          2012.916667          32.0
# 1   2          2012.916667          19.5
# 2   3          2013.583333          13.3
# 3   4          2013.500000          13.3
# 4   5          2012.833333           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# 3     24.98746     121.54391                        54.8
# 4     24.97937     121.54245                        43.1

# %%
df.drop(columns='No', inplace=True) # Drop the column 'No' as it is not necessary
df.head()
# Out:
#    X1 transaction date  X2 house age  X3 distance to the nearest MRT station  \
# 0          2012.916667          32.0                                84.87882
# 1          2012.916667          19.5                               306.59470
# 2          2013.583333          13.3                               561.98450
# 3          2013.500000          13.3                               561.98450
# 4          2012.833333           5.0                               390.56840
#
#    X4 number of convenience stores  X5 latitude  X6 longitude  \
# 0                               10     24.98298     121.54024
# 1                                9     24.98034     121.53951
# 2                                5     24.98746     121.54391
# 3                                5     24.98746     121.54391
# 4                                5     24.97937     121.54245
#
#    Y house price of unit area
# 0                        37.9
# 1                        42.2
# 2                        47.3
# 3                        54.8
# 4                        43.1

# %%
np_array = pd.DataFrame.to_numpy(df) # convert dataframe to numpy array
X = np_array[:,:6] # separate feature set
y = np_array[:,6] # separate output set

# %%
# split data into train and test sets
X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(X,y,test_size = 0.8,
                                                                            train_size=0.2)

# %%
lin_reg = sklearn.linear_model.LinearRegression()
lin_reg.fit(X_train, y_train) # train linear regression model
# Out:
# LinearRegression()

# %%
print(f'The intercept is: {lin_reg.intercept_}') # print intercept
print(f'The coefficients are: {lin_reg.coef_}') # print coefficients
# Out:
# The intercept is: -6624.553883159841
# The coefficients are: [ 2.33330967e+00 -4.31061378e-01 -3.71503543e-03  1.22100881e+00
#   3.48680587e+02 -5.54131174e+01]

# %%
pred = lin_reg.predict(X_test) # predict values from test set using the trained models

# %%
mean_squared_error = sklearn.metrics.mean_squared_error(y_test,pred) # find mean squared error in the predictions
r_sq = sklearn.metrics.r2_score(y_test,pred) # find r_2 in the predictions
print(f'Mean Squared Error is: {mean_squared_error}')
print(f'r_sq is: {r_sq}')
# Out:
# Mean Squared Error is: 94.34023785840638
# r_sq is: 0.5028577402622865

# %%
for i, j in [[0.6, 0.4], [0.7,0.3], [0.9,0.1]]:
    X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(X,y,train_size=i,
                                                                                test_size = j)                                                                                                                                               
    lin_reg = sklearn.linear_model.LinearRegression()
    lin_reg.fit(X_train, y_train)
    print(f'For train set size = {i*100}% of dataset:', end='\n\n')
    print(f'The intercept is: {lin_reg.intercept_}')
    print (f'The coefficients are: {lin_reg.coef_}')
    pred = lin_reg.predict(X_test)
    mean_squared_error = sklearn.metrics.mean_squared_error(y_test,pred)
    r_sq = sklearn.metrics.r2_score(y_test,pred)
    print(f'Mean Squared Error is: {mean_squared_error}')
    print(f'r_sq is: {r_sq}', end='\n\n')
# Out:
# For train set size = 60.0% of dataset:
#
# The intercept is: -19576.817013763302
# The coefficients are: [ 5.02981269e+00 -2.71328994e-01 -3.21599299e-03  1.57454728e+00
#   2.40023765e+02  2.87802292e+01]
# Mean Squared Error is: 97.61849667626569
# r_sq is: 0.4588075327257106
#
# For train set size = 70.0% of dataset:
#
# The intercept is: -7999.260801492228
# The coefficients are: [ 3.77804872e+00 -2.31654700e-01 -5.43398866e-03  9.53068878e-01
#   2.04784688e+02 -3.84708372e+01]
# Mean Squared Error is: 69.2889127694256
# r_sq is: 0.6080953409647518
#
# For train set size = 90.0% of dataset:
#
# The intercept is: -13947.118174007515
# The coefficients are: [ 5.67810114e+00 -2.87175162e-01 -4.87905153e-03  1.08116077e+00
#   2.06943057e+02 -2.14501145e+01]
# Mean Squared Error is: 95.25560914463364
# r_sq is: 0.5073364361390894

# %% [markdown]
# #### We get the minimum mean squared error at train set size = 70%. Before that there is underfitting and after that there is overfitting

# %% [markdown]
# ### Ridge Regression

# %%
for i, j in [[0.6, 0.4], [0.7,0.3], [0.8, 0.2], [0.9,0.1]]:
    for alpha in [0.001, 0.005, 0.01, 0.05, 0.1, 0.5]:
        # break data into train and test sets
        X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(X,y,train_size=i,
                                                                                test_size = j)
        ridge_reg = sklearn.linear_model.Ridge(alpha = alpha) 
        ridge_reg.fit(X_train, y_train) # train ridge regression model
        print(f'For train set size = {i*100}% of dataset and alpha={alpha}:', end='\n\n')
        print(f'The intercept is: {ridge_reg.intercept_}') # print intercept
        print (f'The coefficients are: {ridge_reg.coef_}') # print cofficients
        pred = ridge_reg.predict(X_test)
        mean_squared_error = sklearn.metrics.mean_squared_error(y_test,pred)
        r_sq = sklearn.metrics.r2_score(y_test,pred)
        print(f'Mean Squared Error is: {mean_squared_error}')
        print(f'r_sq is: {r_sq}', end='\n\n')
# Out:
# For train set size = 60.0% of dataset and alpha=0.001:
#
# The intercept is: -16045.46551199843
# The coefficients are: [ 4.96541036e+00 -1.82865401e-01 -3.62189220e-03  1.60689909e+00
#   2.16780525e+02  5.55488782e+00]
# Mean Squared Error is: 96.62589632643196
# r_sq is: 0.47526861714138335
#
# For train set size = 60.0% of dataset and alpha=0.005:
#
# The intercept is: -12734.250816400612
# The coefficients are: [ 6.58889287e+00 -2.86266540e-01 -4.98567087e-03  1.37620986e+00
#   1.34812585e+02 -3.17056220e+01]
# Mean Squared Error is: 110.66608631709003
# r_sq is: 0.4444985295305204
#
# For train set size = 60.0% of dataset and alpha=0.01:
#
# The intercept is: -12803.566063030143
# The coefficients are: [ 5.53781935e+00 -2.84012415e-01 -6.15162423e-03  6.68946571e-01
#   1.61587422e+02 -1.91973274e+01]
# Mean Squared Error is: 70.81021800790406
# r_sq is: 0.6016016703515178
#
# For train set size = 60.0% of dataset and alpha=0.05:
#
# The intercept is: -13127.451473760479
# The coefficients are: [ 6.08167955e+00 -2.13315307e-01 -5.88015599e-03  1.08579706e+00
#   6.12203389e+01 -4.93794115e+00]
# Mean Squared Error is: 63.210045252835805
# r_sq is: 0.6019850405820386
#
# For train set size = 60.0% of dataset and alpha=0.1:
#
# The intercept is: -6761.0801108644855
# The coefficients are: [ 3.05967642e+00 -2.35260100e-01 -5.16997544e-03  1.24681602e+00
#   3.91070992e+01 -2.73805398e+00]
# Mean Squared Error is: 107.67933670931407
# r_sq is: 0.4653514682776706
#
# For train set size = 60.0% of dataset and alpha=0.5:
#
# The intercept is: -10786.894414919856
# The coefficients are: [ 5.39406564e+00 -2.57763221e-01 -5.77499062e-03  1.06366546e+00
#   1.16592328e+01 -2.62262190e+00]
# Mean Squared Error is: 64.36295709113124
# r_sq is: 0.6320111498695578
#
# For train set size = 70.0% of dataset and alpha=0.001:
#
# The intercept is: -12540.147596088795
# The coefficients are: [ 5.74913214e+00 -3.01807286e-01 -4.99072313e-03  9.04965147e-01
#   2.04079189e+02 -3.36055537e+01]
# Mean Squared Error is: 78.76886910415364
# r_sq is: 0.563452499778226
#
# For train set size = 70.0% of dataset and alpha=0.005:
#
# The intercept is: -15881.208406254964
# The coefficients are: [ 6.75090560e+00 -2.60315953e-01 -4.48026519e-03  1.17276708e+00
#   2.04229946e+02 -2.27588726e+01]
# Mean Squared Error is: 57.57901356506741
# r_sq is: 0.6635893817444847
#
# For train set size = 70.0% of dataset and alpha=0.01:
#
# The intercept is: -10609.802789824047
# The coefficients are: [ 5.50796991e+00 -2.60979588e-01 -5.11894987e-03  1.17091373e+00
#   1.50758981e+02 -3.45549271e+01]
# Mean Squared Error is: 62.43532786242536
# r_sq is: 0.6141124036822116
#
# For train set size = 70.0% of dataset and alpha=0.05:
#
# The intercept is: -13648.105819296043
# The coefficients are: [ 6.36663640e+00 -2.72376473e-01 -4.86917750e-03  1.40938805e+00
#   7.57829607e+01 -8.38643358e+00]
# Mean Squared Error is: 104.39568691441735
# r_sq is: 0.4977383085974395
#
# For train set size = 70.0% of dataset and alpha=0.1:
#
# The intercept is: -11804.599178513738
# The coefficients are: [ 5.64137283e+00 -2.53106804e-01 -5.36775046e-03  1.22157786e+00
#   4.96766514e+01 -6.16418573e+00]
# Mean Squared Error is: 98.34698331924797
# r_sq is: 0.5161101381118249
#
# For train set size = 70.0% of dataset and alpha=0.5:
#
# The intercept is: -12239.112260368189
# The coefficients are: [ 6.03966332e+00 -2.92060376e-01 -5.36822834e-03  1.13903061e+00
#   1.22045843e+01 -1.47661137e+00]
# Mean Squared Error is: 67.46441465073455
# r_sq is: 0.6024172194580444
#
# For train set size = 80.0% of dataset and alpha=0.001:
#
# The intercept is: -12248.26930185884
# The coefficients are: [ 4.35895125e+00 -2.94375325e-01 -4.68067242e-03  9.71788952e-01
#   2.35909006e+02 -1.95271579e+01]
# Mean Squared Error is: 91.93505393908639
# r_sq is: 0.5531911139630912
#
# For train set size = 80.0% of dataset and alpha=0.005:
#
# The intercept is: -6367.458502919214
# The coefficients are: [ 5.01938315e+00 -2.95715337e-01 -5.35042576e-03  1.09677066e+00
#   1.86836236e+02 -6.87680261e+01]
# Mean Squared Error is: 65.453920844156
# r_sq is: 0.5792793103707492
#
# For train set size = 80.0% of dataset and alpha=0.01:
#
# The intercept is: -10883.151758437676
# The coefficients are: [ 4.09177319e+00 -2.76913009e-01 -4.82466751e-03  1.03138148e+00
#   1.74628597e+02 -1.37452487e+01]
# Mean Squared Error is: 79.37877761098808
# r_sq is: 0.5998451431967081
#
# For train set size = 80.0% of dataset and alpha=0.05:
#
# The intercept is: -12888.753174362966
# The coefficients are: [ 5.23076266e+00 -2.55489464e-01 -5.04460991e-03  1.36583615e+00
#   8.93057259e+01  1.40594925e+00]
# Mean Squared Error is: 136.80378731543837
# r_sq is: 0.3978449397920808
#
# For train set size = 80.0% of dataset and alpha=0.1:
#
# The intercept is: -12662.426195411637
# The coefficients are: [ 6.16655484e+00 -2.51304056e-01 -5.71640217e-03  1.10142569e+00
#   5.30545955e+01 -8.49176391e+00]
# Mean Squared Error is: 60.17406107486652
# r_sq is: 0.675769506471104
#
# For train set size = 80.0% of dataset and alpha=0.5:
#
# The intercept is: -12489.118695257186
# The coefficients are: [ 6.18549687e+00 -2.80079545e-01 -5.63171826e-03  1.16211333e+00
#   1.52793902e+01 -2.47141907e+00]
# Mean Squared Error is: 66.3602135225555
# r_sq is: 0.5193462601711374
#
# For train set size = 90.0% of dataset and alpha=0.001:
#
# The intercept is: -14068.999786157889
# The coefficients are: [ 5.21015279e+00 -2.55965908e-01 -4.56829611e-03  1.06423872e+00
#   2.24225894e+02 -1.62532715e+01]
# Mean Squared Error is: 24.21747437493242
# r_sq is: 0.7896903719959008
#
# For train set size = 90.0% of dataset and alpha=0.005:
#
# The intercept is: -14366.221530511277
# The coefficients are: [ 4.45204504e+00 -2.72767247e-01 -4.13223977e-03  1.23857534e+00
#   2.10897086e+02  1.47941086e+00]
# Mean Squared Error is: 71.04743034577007
# r_sq is: 0.4318526602377658
#
# For train set size = 90.0% of dataset and alpha=0.01:
#
# The intercept is: -13234.566789581939
# The coefficients are: [ 5.36003927e+00 -2.59910246e-01 -5.00544370e-03  1.20310479e+00
#   1.44823994e+02 -9.28905388e+00]
# Mean Squared Error is: 79.68717174656236
# r_sq is: 0.4925745842909631
#
# For train set size = 90.0% of dataset and alpha=0.05:
#
# The intercept is: -12584.926741970918
# The coefficients are: [ 5.77406748e+00 -2.53899081e-01 -5.02632684e-03  1.23515566e+00
#   9.80900725e+01 -1.18934053e+01]
# Mean Squared Error is: 59.81538957348353
# r_sq is: 0.610500198478998
#
# For train set size = 90.0% of dataset and alpha=0.1:
#
# The intercept is: -11961.049746708157
# The coefficients are: [ 5.60067057e+00 -2.73717494e-01 -5.32314483e-03  1.21011600e+00
#   5.73427092e+01 -5.77714443e+00]
# Mean Squared Error is: 71.59347225433073
# r_sq is: 0.593107874157581
#
# For train set size = 90.0% of dataset and alpha=0.5:
#
# The intercept is: -11319.484836917945
# The coefficients are: [ 5.64108674e+00 -2.55718263e-01 -5.53270233e-03  1.22514686e+00
#   1.35066469e+01 -2.72034901e+00]
# Mean Squared Error is: 54.201475429204116
# r_sq is: 0.6260469674476488

# %% [markdown]
# ### LASSO Regression

# %%
for i, j in [[0.6, 0.4], [0.7,0.3], [0.8, 0.2], [0.9,0.1]]:
    for alpha in [0.001, 0.005, 0.01, 0.05, 0.1, 0.5]:
        # split data into train and test sets
        X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(X,y,train_size=i,
                                                                                test_size = j)
        lasso_reg = sklearn.linear_model.Lasso(alpha = alpha)
        lasso_reg.fit(X_train, y_train) # train lasso model
        print(f'For train set size = {i*100}% of dataset and alpha={alpha}:', end='\n\n')
        print(f'The intercept is: {lasso_reg.intercept_}')
        print (f'The coefficients are: {lasso_reg.coef_}')
        pred = lasso_reg.predict(X_test)
        mean_squared_error = sklearn.metrics.mean_squared_error(y_test,pred)
        r_sq = sklearn.metrics.r2_score(y_test,pred)
        print(f'Mean Squared Error is: {mean_squared_error}')
        print(f'r_sq is: {r_sq}', end='\n\n')
# Out:
# For train set size = 60.0% of dataset and alpha=0.001:
#
# The intercept is: -15937.203168885879
# The coefficients are: [ 5.98338539e+00 -2.62773673e-01 -4.87613466e-03  1.15440467e+00
#   1.69029634e+02 -2.34704254e+00]
# Mean Squared Error is: 52.84186233057155
# r_sq is: 0.643436536132604
#
# For train set size = 60.0% of dataset and alpha=0.005:
#
# The intercept is: -15980.006942113157
# The coefficients are: [ 5.97830053e+00 -2.35780396e-01 -4.50077376e-03  1.42170582e+00
#   1.59650242e+02 -0.00000000e+00]
# Mean Squared Error is: 86.51474597721564
# r_sq is: 0.5183817001677996
#
# For train set size = 60.0% of dataset and alpha=0.01:
#
# The intercept is: -14139.584900076257
# The coefficients are: [ 5.05747709e+00 -2.55509894e-01 -4.43417547e-03  1.29366555e+00
#   1.60205578e+02  0.00000000e+00]
# Mean Squared Error is: 98.81318614295132
# r_sq is: 0.5068583323069571
#
# For train set size = 60.0% of dataset and alpha=0.05:
#
# The intercept is: -16264.481296272903
# The coefficients are: [ 8.10078021e+00 -2.51927356e-01 -5.50770876e-03  1.36805384e+00
#   0.00000000e+00  0.00000000e+00]
# Mean Squared Error is: 46.614169841390456
# r_sq is: 0.6625722579277789
#
# For train set size = 60.0% of dataset and alpha=0.1:
#
# The intercept is: -8735.190464893425
# The coefficients are: [ 4.36060967 -0.25354878 -0.00536511  1.30278497  0.         -0.        ]
# Mean Squared Error is: 56.60058393316478
# r_sq is: 0.6300160652919325
#
# For train set size = 60.0% of dataset and alpha=0.5:
#
# The intercept is: -585.8502958551029
# The coefficients are: [ 0.31175611 -0.26795276 -0.00540523  1.52145034  0.         -0.        ]
# Mean Squared Error is: 126.3189502551544
# r_sq is: 0.3869846460322308
#
# For train set size = 70.0% of dataset and alpha=0.001:
#
# The intercept is: -16986.808933457127
# The coefficients are: [ 5.85920646e+00 -2.98422375e-01 -4.64274405e-03  1.14757477e+00
#   1.94792595e+02  3.05525053e+00]
# Mean Squared Error is: 53.28891134088502
# r_sq is: 0.6540623814785
#
# For train set size = 70.0% of dataset and alpha=0.005:
#
# The intercept is: -17386.47390496365
# The coefficients are: [ 6.25423843e+00 -2.95820491e-01 -4.76849230e-03  1.08864683e+00
#   1.93824819e+02 -0.00000000e+00]
# Mean Squared Error is: 51.657233097757086
# r_sq is: 0.6540875226229163
#
# For train set size = 70.0% of dataset and alpha=0.01:
#
# The intercept is: -13404.842154501033
# The coefficients are: [ 4.41348246e+00 -2.97009138e-01 -4.72859391e-03  1.07088325e+00
#   1.82761418e+02 -0.00000000e+00]
# Mean Squared Error is: 83.04683376373738
# r_sq is: 0.5411373560035486
#
# For train set size = 70.0% of dataset and alpha=0.05:
#
# The intercept is: -10117.545078366727
# The coefficients are: [ 5.04723989 -0.24073186 -0.00550196  1.29201684  0.         -0.        ]
# Mean Squared Error is: 58.09412694024783
# r_sq is: 0.5928465944876588
#
# For train set size = 70.0% of dataset and alpha=0.1:
#
# The intercept is: -5232.187798484537
# The coefficients are: [ 2.62040567 -0.24609262 -0.00552513  1.18493356  0.         -0.        ]
# Mean Squared Error is: 121.82377420481768
# r_sq is: 0.5032275985308776
#
# For train set size = 70.0% of dataset and alpha=0.5:
#
# The intercept is: 42.34214023768926
# The coefficients are: [ 0.         -0.24655929 -0.00512651  1.43007826  0.         -0.        ]
# Mean Squared Error is: 121.72196041335667
# r_sq is: 0.4025390374481925
#
# For train set size = 80.0% of dataset and alpha=0.001:
#
# The intercept is: -16579.33043931335
# The coefficients are: [ 5.66199673e+00 -2.70421326e-01 -4.45725585e-03  1.11668574e+00
#   2.09214398e+02 -0.00000000e+00]
# Mean Squared Error is: 59.82746620010953
# r_sq is: 0.6641108689873448
#
# For train set size = 80.0% of dataset and alpha=0.005:
#
# The intercept is: -14506.733470702977
# The coefficients are: [ 4.47066502e+00 -3.20636583e-01 -4.41950231e-03  1.02284429e+00
#   2.22303382e+02 -0.00000000e+00]
# Mean Squared Error is: 88.4465388527974
# r_sq is: 0.5029815759334724
#
# For train set size = 80.0% of dataset and alpha=0.01:
#
# The intercept is: -14447.055158723517
# The coefficients are: [ 5.93096054e+00 -2.65828707e-01 -5.20615762e-03  1.20316474e+00
#   1.02153909e+02 -0.00000000e+00]
# Mean Squared Error is: 62.3795356288968
# r_sq is: 0.5740828724562055
#
# For train set size = 80.0% of dataset and alpha=0.05:
#
# The intercept is: -8958.920157271055
# The coefficients are: [ 4.47112997 -0.221966   -0.00547758  1.33888705  0.         -0.        ]
# Mean Squared Error is: 128.30870426912307
# r_sq is: 0.481963088284608
#
# For train set size = 80.0% of dataset and alpha=0.1:
#
# The intercept is: -11410.08304014637
# The coefficients are: [ 5.68898136e+00 -2.50433904e-01 -5.27934142e-03  1.37391306e+00
#   0.00000000e+00 -0.00000000e+00]
# Mean Squared Error is: 45.932544669682855
# r_sq is: 0.6388453679182979
#
# For train set size = 80.0% of dataset and alpha=0.5:
#
# The intercept is: 42.48856883518821
# The coefficients are: [ 0.         -0.26388568 -0.0052359   1.46064884  0.         -0.        ]
# Mean Squared Error is: 73.95674748429872
# r_sq is: 0.4233537228859998
#
# For train set size = 90.0% of dataset and alpha=0.001:
#
# The intercept is: -15573.248413301246
# The coefficients are: [ 5.46975428e+00 -2.93751325e-01 -4.69460385e-03  1.11532435e+00
#   1.93861103e+02 -1.93464218e+00]
# Mean Squared Error is: 81.6901486142521
# r_sq is: 0.6045566529557007
#
# For train set size = 90.0% of dataset and alpha=0.005:
#
# The intercept is: -13988.470568515635
# The coefficients are: [ 4.74152465e+00 -2.88530401e-01 -4.60672895e-03  1.12953392e+00
#   1.79686980e+02 -0.00000000e+00]
# Mean Squared Error is: 54.58684185721344
# r_sq is: 0.6275991201557756
#
# For train set size = 90.0% of dataset and alpha=0.01:
#
# The intercept is: -12306.83450064887
# The coefficients are: [ 5.05795293e+00 -2.37978152e-01 -5.51547580e-03  1.03422989e+00
#   8.68402106e+01 -0.00000000e+00]
# Mean Squared Error is: 78.39702874250717
# r_sq is: 0.6486527560654823
#
# For train set size = 90.0% of dataset and alpha=0.05:
#
# The intercept is: -12088.733140402406
# The coefficients are: [ 6.02692935 -0.23947979 -0.00608509  1.10570673  0.         -0.        ]
# Mean Squared Error is: 102.81919155488937
# r_sq is: 0.5482910077084487
#
# For train set size = 90.0% of dataset and alpha=0.1:
#
# The intercept is: -8790.063019884932
# The coefficients are: [ 4.38802132 -0.24175727 -0.00571462  1.20704618  0.         -0.        ]
# Mean Squared Error is: 62.85852485270578
# r_sq is: 0.6434054932286224
#
# For train set size = 90.0% of dataset and alpha=0.5:
#
# The intercept is: 43.63971386773062
# The coefficients are: [ 0.         -0.24316084 -0.00550752  1.18102603  0.         -0.        ]
# Mean Squared Error is: 44.2274835003326
# r_sq is: 0.6991776494445072
